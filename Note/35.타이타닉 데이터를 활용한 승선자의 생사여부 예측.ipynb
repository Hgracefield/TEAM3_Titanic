# %% [markdown]
# #### 타이타닉 데이터를 활용한 승선자의 생사여부 예측
# ##### EDA를 활용한 Feature, Target 구성 여부 확인

# %%
import pandas as pd

# %%
train_df = pd.read_csv("../Data/train.csv")
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# >3 등급은 선실이 없다.
# age 가 없는게 있다.

# %%
# Age의 컬럼 선택 여부 확인 : 결측치가 20%이상이면 해당 컬럼은 사용할 수 없다.
(len(train_df) - train_df.Age.count()) / len(train_df) * 100
# Out:
# np.float64(19.865319865319865)

# %%
print(len(train_df.Age))
print(train_df.Age.count())   # 결측치는 빼고 카운트를 해야함?
# Out:
# 891
# 714

# %%
# age가  null 인것 null이 아닌것을 분류해서 데이터 분석을 할 수 있다.
age_null = train_df[train_df.Age.isnull()]
age_not_null =train_df[train_df.Age.notnull()]
len(age_null) + len(age_not_null)
# Out:
# 891

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# > PassengerId순으로 되어있음. 의미없어서 정렬을 다시 해줌.

# %%
# Survived와 Pclass 기준으로 Dataset 정렬 : 정렬 후 index 재정리 필요
train_df = train_df.sort_values(by = ['Survived', 'Pclass']).reset_index(drop=True)
train_df.iloc[500:520,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 500          785         0       3
# 501          786         0       3
# 502          788         0       3
# 503          791         0       3
# 504          793         0       3
# 505          795         0       3
# 506          799         0       3
# 507          800         0       3
# 508          806         0       3
# 509          808         0       3
# 510          811         0       3
# 511          812         0       3
# 512          814         0       3
# 513          815         0       3
# 514          817         0       3
# 515          819         0       3
# 516          820         0       3
# 517          825         0       3
# 518          826         0       3
# 519          827         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 500                                   Ali, Mr. William    male  25.0      0
# 501                 Harmer, Mr. Abraham (David Lishin)    male  25.0      0
# 502                          Rice, Master. George Hugh    male   8.0      4
# 503                           Keane, Mr. Andrew "Andy"    male   NaN      0
# 504                            Sage, Miss. Stella Anna  female   NaN      8
# 505                              Dantcheff, Mr. Ristiu    male  25.0      0
# 506                       Ibrahim Shawah, Mr. Yousseff    male  30.0      0
# 507  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 508                          Johansson, Mr. Karl Johan    male  31.0      0
# 509                    Pettersson, Miss. Ellen Natalia  female  18.0      0
# 510                             Alexander, Mr. William    male  26.0      0
# 511                                  Lester, Mr. James    male  39.0      0
# 512                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 513                         Tomlin, Mr. Ernest Portage    male  30.5      0
# 514                       Heininen, Miss. Wendla Maria  female  23.0      0
# 515                   Holm, Mr. John Fredrik Alexander    male  43.0      0
# 516                       Skoog, Master. Karl Thorsten    male  10.0      3
# 517                       Panula, Master. Urho Abraham    male   2.0      4
# 518                                    Flynn, Mr. John    male   NaN      0
# 519                                       Lam, Mr. Len    male   NaN      0
#
#      Parch              Ticket     Fare Cabin Embarked
# 500      0  SOTON/O.Q. 3101312   7.0500   NaN        S
# 501      0              374887   7.2500   NaN        S
# 502      1              382652  29.1250   NaN        Q
# 503      0               12460   7.7500   NaN        Q
# 504      2            CA. 2343  69.5500   NaN        S
# 505      0              349203   7.8958   NaN        S
# 506      0                2685   7.2292   NaN        C
# 507      1              345773  24.1500   NaN        S
# 508      0              347063   7.7750   NaN        S
# 509      0              347087   7.7750   NaN        S
# 510      0                3474   7.8875   NaN        S
# 511      0           A/4 48871  24.1500   NaN        S
# 512      2              347082  31.2750   NaN        S
# 513      0              364499   8.0500   NaN        S
# 514      0    STON/O2. 3101290   7.9250   NaN        S
# 515      0              C 7075   6.4500   NaN        S
# 516      2              347088  27.9000   NaN        S
# 517      1             3101295  39.6875   NaN        S
# 518      0              368323   6.9500   NaN        Q
# 519      0                1601  56.4958   NaN        S

# %%
train_df.shape
# Out:
# (891, 12)

# %%
# Survived 기준으로 생존과 사망의 Count 확인
print(f"사망자 수 : {train_df[train_df.Survived == 0].shape[0]}")  # 사망자 수
print(f"생존자 수 : {train_df[train_df.Survived == 1].shape[0]}")  # 생존자 수
# 60% 넘어서 타겟으로 사용 가능
# Out:
# 사망자 수 : 549
# 사망자 수 : 342

# %%
# 생존과 사망의 DataFreame 만들기
result = [train_df[train_df.Survived == 0].shape[0], train_df[train_df.Survived == 1].shape[0]]
live_death = pd.DataFrame(
    {
        'Result' : result
    },
    index= ['사망', '생존']
)
live_death
# Out:
#     Result
# 사망     549
# 생존     342

# %%
# Pie Chart
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
plt.figure(figsize = (14,5))

live_death.Result.plot(
    kind = 'pie',
    autopct = '%.2f%%'
)
plt.title('타이타닉호의 생존과 사망 비율')
plt.axis('equal')
plt.ylabel('')

plt.show()

# %% [markdown]
# > Target의 비율이 60%보다 크므로 Target으로 약간 아쉽지만 적합하다.

# %% [markdown]
# ----
# Feature 컬럼 선택

# %%
train_df.head()
# 쉬운 데이터 = 결측치 없고 분류하기쉬워야함. =>  성별, pclass
# target의 비율은 1:1, Feature의 비율은 차이가 나야함. 1:1은 x 구분할 수 없음.
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 1           28         0       1  Fortune, Mr. Charles Alexander  male  19.0
# 2           31         0       1        Uruchurtu, Don. Manuel E  male  40.0
# 3           35         0       1         Meyer, Mr. Edgar Joseph  male  28.0
# 4           36         0       1  Holverson, Mr. Alexander Oskar  male  42.0
#
#    SibSp  Parch    Ticket      Fare        Cabin Embarked
# 0      0      0     17463   51.8625          E46        S
# 1      3      2     19950  263.0000  C23 C25 C27        S
# 2      0      0  PC 17601   27.7208          NaN        C
# 3      1      0  PC 17604   82.1708          NaN        C
# 4      1      0    113789   52.0000          NaN        S

# %% [markdown]
# #### Sex컬럼이 Feature로 적합한지 확인
# : null도 없고 category갯수도 적다.

# %%
train_df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
314/577
# Out:
# 0.5441941074523396

# %% [markdown]
# > 남성의 승선수가 여성의 승선수 보다 거의 2배이다.
# Feature는 차이가 특성이 필요한데, 일단 승선수만 보면 Feature로 사용할 수 있을 것 같다.

# %% [markdown]
# #### Target 컬럼과 연결하여 Feature가 될 수 있는지 확인

# %%
# 여성의 생존과 사망수 
female_survived = train_df[(train_df.Sex == 'female') & (train_df.Survived == 1)].shape[0]
female_death = train_df[(train_df.Sex == 'female') & (train_df.Survived == 0)].shape[0]

print(f"여성의 생존수는 {female_survived}이고 사망수는 {female_death}이다")
# Out:
# 여성의 생존수는 233이고 사망수는 81이다

# %%
# 남성의 생존과 사망수 
male_survived = train_df[(train_df.Sex == 'male') & (train_df.Survived == 1)].shape[0]
male_death = train_df[(train_df.Sex == 'male') & (train_df.Survived == 0)].shape[0]

print(f"남성의 생존수는 {male_survived}이고 사망수는 {male_death}이다")
# Out:
# 남성의 생존수는 109이고 사망수는 468이다

# %% [markdown]
# > 여성과 남성의 생존여부를 연결하여 특징을 보았는데 성별로 정반대의 특징이 나타난다.
# Sex컬럼은 Feature로서 충분하다.

# %%
# 둘 사이의 파이차트 그리기
result_gender = train_df.
# Out:
# 0.2329059829059829

# %% [markdown]
# ----
# ### Pclass의 Feature 확인

# %%
# Pclass의 Category 분포 확인
train_df.Pclass.value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %% [markdown]
# > 객실의 등급별 인원수로 보아 1, 2등급은 크게 차이나지 않지만, 1과 3 그리고 2와 3을 차이가 있어 Feature의 가능성이 보임

# %% [markdown]
# #### [Survived] <-> [Sex, Pclass확인]

# %%
# 1등급 객실의 여성 생존율
female_count = train_df[(train_df.Sex == 'female') & (train_df.Pclass == 1)].shape[0]
female_live = train_df[(train_df.Sex == 'female') & (train_df.Pclass == 1) & (train_df.Survived == 1)].shape[0]

print(f"1등급 객실의 여성의 생존율을 {female_live} / {female_count}로 {round(female_live/female_count*100)}% 이다")
# Out:
# 1등급 객실의 여성의 생존율을 91 / 94로 97% 이다

# %%
# 1, 2, 3등 객실의 여성 생존률

for i in train_df.Pclass.unique():
    female_count = train_df[(train_df.Sex == 'female') & (train_df.Pclass == i)].shape[0]
    female_live = train_df[(train_df.Sex == 'female') & (train_df.Pclass == i) & (train_df.Survived == 1)].shape[0]
    print(f"{i}등급 객실의 여성의 생존율을 {female_live} / {female_count}로 {round(female_live/female_count*100)}% 이다")
# Out:
# 1등급 객실의 여성의 생존율을 91 / 94로 97% 이다
# 2등급 객실의 여성의 생존율을 70 / 76로 92% 이다
# 3등급 객실의 여성의 생존율을 72 / 144로 50% 이다

# %%
# 1, 2, 3등급 객실의 여성 남성 생존률
for gender in train_df.Sex.unique():
    for i in train_df.Pclass.unique():
        male_count = train_df[(train_df.Sex == gender) & (train_df.Pclass == i)].shape[0]
        male_live = train_df[(train_df.Sex == gender) & (train_df.Pclass == i) & (train_df.Survived == 1)].shape[0]
        print(f"{i}등급 객실의 {"남성" if gender == 'male' else '여성'}의 생존율을 {male_live} / {male_count:>3}로 {male_live/male_count*100:.2f} 이다")
    print('-' * 50)
# Out:
# 1등급 객실의 남성의 생존율을 45 / 122로 36.89 이다
# 2등급 객실의 남성의 생존율을 17 / 108로 15.74 이다
# 3등급 객실의 남성의 생존율을 47 / 347로 13.54 이다
# --------------------------------------------------
# 1등급 객실의 여성의 생존율을 91 /  94로 96.81 이다
# 2등급 객실의 여성의 생존율을 70 /  76로 92.11 이다
# 3등급 객실의 여성의 생존율을 72 / 144로 50.00 이다
# --------------------------------------------------

# %% [markdown]
# #### [Survived] <-> [Sex, Pclass]로 결정

# %%
train_df.Embarked.unique()
# nan 값 찾아야함
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
# NaN인 데이터 찾기
train_df[train_df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 556           62         1       1                        Icard, Miss. Amelie
# 672          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 556  female  38.0      0      0  113572  80.0   B28      NaN
# 672  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# 항구별 승선 인원
train_df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# > s항구가 수치가 높기 때문에 S항수로 nan값을 변환

# %%
train_df.loc[train_df.Embarked.isnull(), 'Embarked'] = "S"
train_df.Embarked.value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# 항구별 성별 승선 인원
train_df.groupby(
    ['Embarked', 'Sex']
).size()
# Out:
# Embarked  Sex
# C         female     73
#           male       95
# Q         female     36
#           male       41
# S         female    205
#           male      441
# dtype: int64

# %%
# 항구별 생존 인원
train_df.groupby(
    ['Embarked', 'Survived']
).size()
# Out:
# Embarked  Survived
# C         0            75
#           1            93
# Q         0            47
#           1            30
# S         0           427
#           1           219
# dtype: int64

# %%
# 항구별 객실등급 인원
train_df.groupby(
    ['Embarked', 'Pclass']
).size()
# Out:
# Embarked  Pclass
# C         1          85
#           2          17
#           3          66
# Q         1           2
#           2           3
#           3          72
# S         1         129
#           2         164
#           3         353
# dtype: int64

# %% [markdown]
# ----
# [Survived] <- [Sex, Pclass, Embarked]

# %%
train = train_df[['Survived', 'Sex', 'Pclass', 'Embarked']]
train.head()
# Out:
#    Survived   Sex  Pclass Embarked
# 0         0  male       1        S
# 1         0  male       1        S
# 2         0  male       1        C
# 3         0  male       1        C
# 4         0  male       1        S

# %%
# Sex컬럼을 SexCode로 숫자화 시킨다.
train.loc[train.Sex == 'female', 'SexCode'] = 0
train.loc[train.Sex == 'male', 'SexCode'] = 1
train.head()
# Out:
#    Survived   Sex  Pclass Embarked  SexCode
# 0         0  male       1        S      1.0
# 1         0  male       1        S      1.0
# 2         0  male       1        C      1.0
# 3         0  male       1        C      1.0
# 4         0  male       1        S      1.0

# %%
# Sex컬럼 삭제
train.drop('Sex', axis=1, inplace = True)
# del train['Sex']

# %%
train.head()
# Out:
#    Survived  Pclass Embarked  SexCode
# 0         0       1        S      1.0
# 1         0       1        S      1.0
# 2         0       1        C      1.0
# 3         0       1        C      1.0
# 4         0       1        S      1.0

# %%
# One-hot-encoding으로 Embarked 정리
train_ml = \
    pd.get_dummies(
        data = train,
        columns=['Embarked']
    )
train_ml.head()
# Out:
#    Survived  Pclass  SexCode  Embarked_C  Embarked_Q  Embarked_S
# 0         0       1      1.0       False       False        True
# 1         0       1      1.0       False       False        True
# 2         0       1      1.0        True       False       False
# 3         0       1      1.0        True       False       False
# 4         0       1      1.0       False       False        True

# %% [markdown]
# ---
# #### Random Forest로 예측 확인

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import train_test_split

# %%
# Train과 Test 분리
train_data, test_data, train_target, test_target = train_test_split(
                                                train_ml.loc[:, 'Pclass':],
                                                train_ml['Survived'],
                                                random_state=42,
                                                stratify=train_ml['Survived']
)

# %%
print(train_data.shape)
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (668, 5)
# (223, 5)
# (668,)
# (223,)

# %%
# 데이터 학습시키고 예측하기
clf = RandomForestClassifier()
clf.fit(train_data, train_target)
print("Train:", clf.score(train_data, train_target))
print("Test:", clf.score(test_data, test_target))
# Out:
# Train: 0.8053892215568862
# Test: 0.8295964125560538

# %% [markdown]
# > 과소적합

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
pred = clf.predict(test_data)

# %%
accuracy_score(test_target, pred)
# Out:
# 0.8295964125560538

# %%
conf_matrix = confusion_matrix(test_target, pred)
conf_matrix
# Out:
# array([[131,   6],
#        [ 32,  54]])

# %%
print('사망 :', 131/(131+6))
print('생존 :', 54/(32+54))
# Out:
# 사망 : 0.9562043795620438
# 생존 : 0.627906976744186

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(
                clf,
                train_ml.loc[:, 'Pclass':],
                train_ml['Survived'],
                cv = 5,
                scoring='accuracy'
)
scores
# Out:
# array([0.54189944, 0.83707865, 0.89325843, 0.76966292, 0.64606742])

# %%
scores.mean()
# Out:
# np.float64(0.737593371414224)

# %% [markdown]
# -------
# -------

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15880\253598515.py in ?()
#       1 train_df[train_df.SibSp == 0].value_counts()
#       2
# ----> 3 for i in train_df.Family.unique():
#       4     for pc in train_df.Pclass.unique():
#       5         train_price = train_df[(train_df.SibSp == i) & (train_df.Parch == i) & (train_df.Pclass == pc) & (train_df.Survived == i)].shape[0]
#       6         print(f"{i} 탄 사람은 {pc}등급 에서 ")
#
# c:\Users\tjoeun\anaconda3\envs\py312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Family'

# %%
train_price = train_df[(train_df.SibSp == 0) & (train_df.Parch == 0) & (train_df.Pclass == 1) & (train_df.Survived == 1)].value_counts()
train_price
